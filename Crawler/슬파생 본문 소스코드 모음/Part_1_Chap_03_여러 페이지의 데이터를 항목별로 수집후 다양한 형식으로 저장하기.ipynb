# %%
# riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
import time 

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(여러개일 경우 , 로 구분하여 입력): ')

#Step 3. 수집된 데이터를 저장할 파일 이름 입력받기 
ft_name = input('2.결과를 저장할 txt형식의 파일명을 쓰세요(예: c:\\temp\\riss.txt): ')
fc_name = input('3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\\temp\\riss.csv): ')
fx_name = input('4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\\temp\\riss.xls): ')

#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
chrome_path = "c:/temp/chromedriver_85/chromedriver.exe"
driver = webdriver.Chrome(chrome_path)

url = 'http://www.riss.kr/'
driver.get(url)
time.sleep(2)

#Step 5. 자동으로 검색어 입력 후 조회하기
element = driver.find_element_by_id("query")
driver.find_element_by_id("query").click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

#Step 6.학위 논문 선택하기
driver.find_element_by_link_text('학위논문').click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('div','srchResultListW').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n",""))

#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력받기
import math
total_cnt = soup_1.find('div','searchBox pd').find('span','num').get_text()
print('검색하신 키워드 %s (으)로 총 %s 건의 학위논문이 검색되었습니다' %(query_txt,total_cnt))
collect_cnt = int(input('이 중에서 몇 건을 수집하시겠습니까?: '))
collect_page_cnt = math.ceil(collect_cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(collect_cnt,collect_page_cnt))

#Step 9. 각 항목별로 데이터를 추출하여 리스트에 저장하기
no2 = [ ]        #번호 저장
title2 = [ ]     #논문제목 저장
writer2 = [ ]    #논문저자 저장
org2 = [ ]       #소속기관 저장
no = 1

# 다음 페이지 번호 만들기
page_no=[ ]

for i in range(10,collect_cnt) :
    if i % 10 == 0 :
            page_no.append(i + 1)

for a in range(1, collect_page_cnt + 1) :
    
    html_2 = driver.page_source
    soup_2 = BeautifulSoup(html_2, 'html.parser')

    content_2 = soup_2.find('div','srchResultListW').find_all('li')
    
    for b in content_2 :    
        #1. 논문제목 있을 경우만
        try :
            title = b.find('div','cont').find('p','title').get_text()
        except :
            continue
        else :
            f = open(ft_name, 'a' , encoding="UTF-8")
            print('1.번호:',no)
            no2.append(no)
            f.write('\n'+'1.번호:' + str(no))

            print('2.논문제목:',title)
            title2.append(title)
            f.write('\n' + '2.논문제목:' + title)
            
            writer = b.find('span','writer').get_text()
            print('3.저자:',writer)
            writer2.append(writer)
            f.write('\n' + '3.저자:' + writer)

            org = b.find('span','assigned').get_text()
            print('4.소속기관:' , org)
            org2.append(org)
            f.write('\n' + '4.소속기관:' + org + '\n')
            
            f.close( )
            
            no += 1
            print("\n")
            
            if no > collect_cnt :
                break

            time.sleep(1)        # 페이지 변경 전 1초 대기 

        c = math.floor(a/10)-1 
        a += 1

        if a == page_no[c]:
            driver.find_element_by_link_text('다음 페이지로').click()
        else :
            driver.find_element_by_link_text('%s' %a).click() # 다음 페이지번호 클릭
        
print("요청하신 작업이 모두 완료되었습니다")

# Step 10. 수집된 데이터를 xls와 csv 형태로 저장하기
import pandas as pd 

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(writer2)
df['소속(발행)기관']=pd.Series(org2)

# xls 형태로 저장하기
df.to_excel(fx_name,index=False, encoding="utf-8")

# csv 형태로 저장하기
df.to_csv(fc_name,index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 1.수집할 자료의 키워드는 무엇입니까?(여러개일 경우 , 로 구분하여 입력): 해양자원
# 2.결과를 저장할 txt형식의 파일명을 쓰세요(예: c:\temp\riss.txt): c:\temp\riss.txt
# 3.결과를 저장할 csv형식의 파일명을 쓰세요(예: c:\temp\riss.csv): c:\temp\riss.csv
# 4.결과를 저장할 xls형식의 파일명을 쓰세요(예: c:\temp\riss.xls): c:\temp\riss.xls
# 1지속가능한 해양관광 발전방안에 대한 연구 :관광자원개발을 중심으로김선종연세대학교 행정대학원2008국내석사RANK : 13634431원문보기음성듣기
# 원문보기
# 음성듣기
# 2해양관광 자원 개발에 대한 연구 :중국 칭다오와 부산을 중심으로장잉잉경기대학교 대학원2019국내석사RANK : 13634431원문보기목차검색조회음성듣기
# 원문보기
# 목차검색조회
# 음성듣기
# 3해양관광유형과 관광자원 가치가 주민참여의도에 미치는 영향 :당진시를 중심으로이길호경기대학교 관광전문대학원2014국내박사RANK : 13634431원문보기목차검색조회음성듣기
# 원문보기
# 목차검색조회
# 음성듣기
# 4해양경계획정 이전 권원중첩수역에서의 자원개발과 환경보호이영주연세대학교 대학원2014국내석사RANK : 13634431원문보기음성듣기
# 원문보기
# 음성듣기
# 5島嶼觀光資源開發이 海洋觀光産業에 미치는 經濟的 波及效果김두성부산대학교2012국내박사RANK : 13634431원문보기목차검색조회음성듣기
# 원문보기
# 목차검색조회
# 음성듣기
#
# 4.소속기관: 서울대학교 대학원
#
#
# 1.번호: 12
# 2.논문제목: 체계적 해양교통안전관리를 위한 현장 인적자원시스템 설계에 관한 연구
# 3.저자: 김수옥
# 4.소속기관: 한국해양대학교 대학원
#
#
# 1.번호: 13
# 2.논문제목: 해양관광자원의 비시장가치 추정에 관한 연구
# 3.저자: 박미옥
# 4.소속기관: 동명대학교 대학원
#
#
# 1.번호: 14
# 2.논문제목: 한국 남해안의 해양환경, 어류종조성 및 자원밀도변동(2004~2008)
# 3.저자: 주현
# 4.소속기관: 全南大學校
#
#
# 1.번호: 15
# 2.논문제목: 군산 오식군도의 신석기-청동기시대 해양자원 이용 연구
# 3.저자: 신숙현
# 4.소속기관: 원광대학교 일반대학원
#
#
# 1.번호: 16
# 2.논문제목: 해양광물자원 개발을 위한 남태평양 지역기구와의 협력방안에 대한 연구 :특히 SOPAC과의 협력을 중심으로
# 3.저자: 허민경
# 4.소속기관: 서울대학교 행정대학원
#
#
# 1.번호: 17
# 2.논문제목: 해양자원을 이용한 두부응고제 개발 연구 :해양부산물을 이용한 천연두부응고제 개발
# 3.저자: 오현의
# 4.소속기관: 세종대학교 대학원
#
#
# 1.번호: 18
# 2.논문제목: 海洋에 關한 國際立法의 方向 :海産資源保存問題를 中心으로
# 3.저자: 강대경
# 4.소속기관: 고려대학교
#
#
# 1.번호: 19
# 2.논문제목: 해양자원이송용 강관의 다양한 하중에 대한 거동 분석
# 3.저자: 권판기
# 4.소속기관: 호서대학교 대학원
#
#
# 1.번호: 20
# 2.논문제목: 한국 서남해안 완도해역의 유용 해양 무척추동물자원의 분포
# 3.저자: 정태원
# 4.소속기관: 조선대학교 대학원
#
#
# 1.번호: 21
# 2.논문제목: 海洋 資源開發과 海洋法에 관한 硏究
# 3.저자: 안용찬
# 4.소속기관: 延世大學校
#
#
# 1.번호: 22
# 2.논문제목: 해양자원으로부터 분리한 Eicosapentaenoic Acid 생산 균주인 Shewanella sp. 215의 동정 및 특성 분석
# 3.저자: 김동욱
# 4.소속기관: 인하대학교 일반대학원
#
#
# 1.번호: 23
# 2.논문제목: 海洋性 觀光資源 開發方向에 관한 硏究
# 3.저자: 김인환
# 4.소속기관: 부산대학교
#
#
# 1.번호: 24
# 2.논문제목: 북태평양의 기후변화에 따른 우리나라 해역별 해양환경 및 수산생물 자원의 반응과 기작
# 3.저자: 정해근
# 4.소속기관: 강릉원주대학교
#
#
# 1.번호: 25
# 2.논문제목: 해양 침전토로부터 유전자형 메타게놈 자원 확보와 lipase 유전자 탐색
# 3.저자: 李漢那
# 4.소속기관: 明知大學校 大學院
#
#
# 1.번호: 26
# 2.논문제목: 島嶼 地域 아동의 해양 탐구력과 수산 자원 보전 의식 鼓吹에 關한 硏究
# 3.저자: 가종훈
# 4.소속기관: 한국교원대학교
#
#
# 1.번호: 27
# 2.논문제목: Aminopyridinol 계 화합물 및 해양생물 자원의 생리활성 스크리닝
# 3.저자: 백남혁
# 4.소속기관: 한양대학교 대학원
#
#
# 1.번호: 28
# 2.논문제목: 海洋觀光資源開發에 관한 硏究 :邊山半島를 中心으로
# 3.저자: 박명엽
# 4.소속기관: 경기대학교 대학원
#
#
# 1.번호: 29
# 2.논문제목: 국가관할권이원지역 해양생물자원의 이용과 규율 :UN해양법협약 원칙의 확장적 적용가능성을 중심으로
# 3.저자: 서진웅
# 4.소속기관: 성균관대학교
#
#
# 1.번호: 30
# 2.논문제목: 해양관광자원을 활용한 제주 신양항 리모델링 계획
# 3.저자: 김예림
# 4.소속기관: 서울대학교 환경대학원
#
#
# 요청하신 작업이 모두 완료되었습니다
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
