# %%
# 1:22
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import math
import os
import pandas as pd

print("="*80)
print("\n")
print("                             유튜브 크롤링")
print("\n")
print("="*80)
print("\n")

query_txt = "유튜브"
query_url = "https://www.youtube.com/"
search_txt = input('''1.크롤링할 검색어를 입력하세요: ''')
count = int(input('''2.몇 건을 가져오겠습니까?: '''))
f_dir = input('3.파일을 저장할 폴더명만 쓰세요.(엔터 입력시 C:/data2/에 저장됨): ')
if f_dir == '':
    f_dir = '/data2/'


print("\n")
print("  요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요")

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+search_txt)
os.chdir(f_dir+s+'-'+query_txt+'-'+search_txt)

ff_dir=f_dir+s+'-'+query_txt+'-'+search_txt
fc_name=f_dir+s+'-'+query_txt+'-'+search_txt+'\\'+s+'-'+query_txt+'-'+search_txt+'.csv'

img_dir = ff_dir+"\\images"
os.makedirs(img_dir)
os.chdir(img_dir)

s_time = time.time( )

chrome_path = "C:/data/chromedriver"
driver = webdriver.Chrome(chrome_path)

driver.get(query_url)
time.sleep(3)

time.sleep(5)
element = driver.find_element_by_name("search_query")
element.send_keys(search_txt)
element.submit()
time.sleep(2)

cnt = 1 

def scroll_down(driver):
    driver.execute_script("window.scrollBy(0,3000);")
    time.sleep(5)

if count < 24 :
    page_cnt = 1 
else :
    page_cnt = math.ceil(count/24)

if count > 24 :
    i = 1
    
    while ( i <=  page_cnt) :
        print("화면을 %s 회 아래로 스크롤 합니다" %i)
        scroll_down(driver)
        time.sleep(1)
        i += 1

no_list = []
title_list = []
thumbnail_list = []
channelname_list = []
period_list = []
length_lsit = []
summary_list = []


html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
item = soup.find('ytd-section-list-renderer', 'style-scope ytd-two-column-search-results-renderer')
item2 = item.find_all('ytd-video-renderer')
print(item2)

no = 1
for j in item2:

    # 키워드에 따른 변수 크롤링


    # 번호
    print("-"*80)
    print('번호: ', no)
    no_list.append(no)
    no += 1

    
    #ytd-video-renderer



    # 제목

#     title = j.find("yt-formatted-string")
#     title2 = title.get_text()
#     print(title2)
#     title_list.append(title2)

    # 썸네일



    # 채널명

   
    # 기간


    # 길이

    # 요약
    try:
        summary = j.find("yt-formatted-string", "metadata-snippet-text-navigation style-scope ytd-video-renderer")   
    except:
        title = '요약이 없습니다.'
        print(summary.replace("\n",""))
    else:
        summary2 = summary.get_text()
        print("요약: ", summary2)
        summary_list.append(summary2)
    if no > count:
        break
    print("-"*80)    
    print("\n")


    
    
'''
썸네일
제목
채널명
기간
길이
요약

기간은?
- 오늘
- 이번주
- 이번달
- 올해
'''

#csv로 저장

df = pd.DataFrame()
df['번호']=pd.Series(no_list)
#df['제목']=pd.Series(title_list)
# df['채널명']=pd.Series(channel_list)
# df['기간']=pd.Series(period_list)
df['요약']=pd.Series(summary_list, dtype = "string")
# df['길이']=pd.Series(length_list)


# 엑셀 형태로 저장하기
df.to_csv(fc_name, encoding="utf-8-sig",index=False)

        
        
        

#마지막 요약정보 출력   
e_time = time.time( )
t_time = e_time - s_time

print("\n")
print("=" *100)
print("총 소요시간: %s 초" %round(t_time,1))
print("총 저장 건수: %s 건 " %count)
print("파일 저장 경로: %s" %fc_name)
print("=" *100)

driver.close( )
# Out:
# ================================================================================
#
#
#                              유튜브 크롤링
#
#
# ================================================================================
#
#
# 1.크롤링할 검색어를 입력하세요: 무한도전
# 2.몇 건을 가져오겠습니까?: 10
# 3.파일을 저장할 폴더명만 쓰세요.(엔터 입력시 C:/data2/에 저장됨):
#
#
#   요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요
# [<ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=XVoisVqgrYw" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/XVoisVqgrYw/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLCWFqxlBT13JkhxgoBtBuSxNZ96aA" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="15분 17초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   15:17
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송 게시자: 옛능 : MBC 옛날 예능 다시보기 7시간 전 15분 조회수 16,915회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=XVoisVqgrYw" id="video-title" title="[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송 게시자: 옛능 : MBC 옛날 예능 다시보기 7시간 전 15분 조회수 16,915회" class="style-scope ytd-video-renderer">[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 1.6만회</span>
# <span class="style-scope ytd-video-meta-block">7시간 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer">[무도의 7월은 어땠을까?] 치킨이 아니고 크로커다일..? KFC=치킨인 줄 알았던 선발팀   ??? : 너네집에서 모일건데 너도 올래?</yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer">[무도의 7월은 어땠을까?] 치킨이 아니고 크로커다일..? KFC=치킨인 줄 알았던 선발팀   ??? : 너네집에서 모일건데 너도 올래?</yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">새 동영상</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=ySn7zXzuA98" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/ySn7zXzuA98/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLBbg3ZQCwsZ-OngjKxmPvDNsC4k4w" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="18분 11초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   18:11
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송 게시자: 옛능 : MBC 옛날 예능 다시보기 1일 전 18분 조회수 73,054회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=ySn7zXzuA98" id="video-title" title="[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송 게시자: 옛능 : MBC 옛날 예능 다시보기 1일 전 18분 조회수 73,054회" class="style-scope ytd-video-renderer">[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 7.3만회</span>
# <span class="style-scope ytd-video-meta-block">1일 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20090704 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20090704 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">새 동영상</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=5gEgBSf106Y" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/5gEgBSf106Y/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLC1Vdij01frMX4aj3pIgfFWNevwMA" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="10분 6초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   10:06
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송 게시자: 오분순삭 2개월 전 10분 6초 조회수 2,198,900회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=5gEgBSf106Y" id="video-title" title="전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송 게시자: 오분순삭 2개월 전 10분 6초 조회수 2,198,900회" class="style-scope ytd-video-renderer">전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC9idb-NIhZrI6wkPesc3MUg" spellcheck="false">오분순삭</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     오분순삭
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 219만회</span>
# <span class="style-scope ytd-video-meta-block">2개월 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UC9idb-NIhZrI6wkPesc3MUg">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLRI95ASduGRz4-nbRu3X91TRRW4z7FxZITINM_1OQ=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC9idb-NIhZrI6wkPesc3MUg" spellcheck="false">오분순삭</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     오분순삭
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">회의시간보다 오래 걸리는 무한상사의 점심 메뉴 고르는 시간,,⏱ *</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 다시 보기 ✓옛능에서 관련 에피소드 더보기   ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">회의시간보다 오래 걸리는 무한상사의 점심 메뉴 고르는 시간,,⏱ *</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 다시 보기 ✓옛능에서 관련 에피소드 더보기   ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=MyOoYJPQK9w" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/MyOoYJPQK9w/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLDzk16HTllp4kjxqX282xjjONAsOQ" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="19분 42초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   19:42
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 11개월 전 19분 조회수 2,455,759회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=MyOoYJPQK9w" id="video-title" title="[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 11개월 전 19분 조회수 2,455,759회" class="style-scope ytd-video-renderer">[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 245만회</span>
# <span class="style-scope ytd-video-meta-block">11개월 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">[무도의 8월은 어땠을까?] 비가 와도 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto">은 멈추지 않는다! 이 위기를 같이 극복할 소중한 친구 찾기 섭외 전화부터 일단 나온다고 ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">[무도의 8월은 어땠을까?] 비가 와도 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto">은 멈추지 않는다! 이 위기를 같이 극복할 소중한 친구 찾기 섭외 전화부터 일단 나온다고 ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=u95CurothXQ" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/u95CurothXQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLBXgWKLn68qAPKf0K_PHuzBXu276g" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="19분 52초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   19:52
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[7月의 무도] 까먹었는데요🤔 뜻밖의 웃음참기 메이커 명수와 웃음지옥에 갇힌 다섯 사나이😭 “진짜 사나이” 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 1년 전 19분 조회수 2,854,577회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=u95CurothXQ" id="video-title" title="[7月의 무도] 까먹었는데요🤔 뜻밖의 웃음참기 메이커 명수와 웃음지옥에 갇힌 다섯 사나이😭 “진짜 사나이” 1편 infinite challenge">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[7月의 무도] 까먹었는데요🤔 뜻밖의 웃음참기 메이커 명수와 웃음지옥에 갇힌 다섯 사나이😭 “진짜 사나이” 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 1년 전 19분 조회수 2,854,577회" class="style-scope ytd-video-renderer">[7月의 무도] 까먹었는데요🤔 뜻밖의 웃음참기 메이커 명수와 웃음지옥에 갇힌 다섯 사나이😭 “진짜 사나이” 1편 infinite challenge</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 285만회</span>
# <span class="style-scope ytd-video-meta-block">1년 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# ...
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20130323 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20130323 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=JNtPVcG67jY" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="15분 49초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   15:49
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[무도] 제 한쪽 귀가 왜 없는지 아세요?👂 퀴즈 풀다가 전설의 짝귀에게 호되게 혼난 우리의 박 씨...💫 '선물장만퀴즈' 2편 MBC130202방송 게시자: 옛능 : MBC 옛날 예능 다시보기 5개월 전 15분 조회수 819,437회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=JNtPVcG67jY" id="video-title" title="[무도] 제 한쪽 귀가 왜 없는지 아세요?👂 퀴즈 풀다가 전설의 짝귀에게 호되게 혼난 우리의 박 씨...💫 '선물장만퀴즈' 2편 MBC130202방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[무도] 제 한쪽 귀가 왜 없는지 아세요?👂 퀴즈 풀다가 전설의 짝귀에게 호되게 혼난 우리의 박 씨...💫 '선물장만퀴즈' 2편 MBC130202방송 게시자: 옛능 : MBC 옛날 예능 다시보기 5개월 전 15분 조회수 819,437회" class="style-scope ytd-video-renderer">[무도] 제 한쪽 귀가 왜 없는지 아세요?👂 퀴즈 풀다가 전설의 짝귀에게 호되게 혼난 우리의 박 씨...💫 '선물장만퀴즈' 2편 MBC130202방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 81만회</span>
# <span class="style-scope ytd-video-meta-block">5개월 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">[무도의 2월은 어땠을까?] 뭐야 내 설 연휴 돌려 줘요;; 떠나가 버린 설 연휴를 그리워하며 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 선물장만퀴즈 보기! 밑도 끝도 없는 ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">[무도의 2월은 어땠을까?] 뭐야 내 설 연휴 돌려 줘요;; 떠나가 버린 설 연휴를 그리워하며 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 선물장만퀴즈 보기! 밑도 끝도 없는 ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>]
# --------------------------------------------------------------------------------
# 번호:  1
# 요약:  [무도의 7월은 어땠을까?] 치킨이 아니고 크로커다일..? KFC=치킨인 줄 알았던 선발팀   ??? : 너네집에서 모일건데 너도 올래?
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  2
# 요약:  방영일자 : 20090704 무한도전 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  3
# 요약:  회의시간보다 오래 걸리는 무한상사의 점심 메뉴 고르는 시간,,⏱ *무한도전 다시 보기 ✓옛능에서 관련 에피소드 더보기   ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  4
# 요약:  [무도의 8월은 어땠을까?] 비가 와도 무한도전은 멈추지 않는다! 이 위기를 같이 극복할 소중한 친구 찾기 섭외 전화부터 일단 나온다고 ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  5
# 요약:  ... 명의 남자들과 그들을 웃음지옥으로 보내버린 단 한 명의 guy,, 방영일자 : 20170701 무한도전 1화부터 FULL버전 다시 보기 (2006 ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  6
# 요약:  [무도의 4월은 어땠을까?] 무한도전 10주년 기념 스태프 앙케트   Q. 오디오 꺼버리고 싶은 멤버는? Q. 가장 찍고 싶은 멤버 순위는?
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  7
# 요약:  ... 방영일자 : 20140816 ⏰오분순삭⏰ 에서 관련 에피소드 보기 '♨유느의 분노 폭발 타임♨' https://youtu.be/HB7YEZx-IM0 무한도전 1 ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  8
# 요약:  방영일자 : 20100717, 20100724 무한도전 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  9
# 요약:  ... 김태호' https://youtu.be/E_n9iHXf3kQ '아이디가 있었는데요 없었습니다' https://youtu.be/TFWdN5s2-EU 무한도전 1화부터 FULL ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  10
# 요약:  ... 에서 관련 에피소드 보기 '[어둑시니pick] 무도 납량특집 모음' https://youtu.be/kYSxsLVSnlo 무한도전 1화부터 FULL버전 다시 보기 ...
#
#
# ====================================================================================================
# 총 소요시간: 17.4 초
# 총 저장 건수: 10 건
# 파일 저장 경로: /data2/2021-07-17-01-21-24-유튜브-무한도전\2021-07-17-01-21-24-유튜브-무한도전.csv
# ====================================================================================================

# %%
# 2:00
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import math
import os
import pandas as pd

print("="*80)
print("\n")
print("                             유튜브 크롤링")
print("\n")
print("="*80)
print("\n")

query_txt = "유튜브"
query_url = "https://www.youtube.com/"
search_txt = input('''1.크롤링할 검색어를 입력하세요: ''')
count = int(input('''2.몇 건을 가져오겠습니까?: '''))
f_dir = input('3.파일을 저장할 폴더명만 쓰세요.(엔터 입력시 C:/data2/에 저장됨): ')
if f_dir == '':
    f_dir = '/data2/'


print("\n")
print("  요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요")

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+search_txt)
os.chdir(f_dir+s+'-'+query_txt+'-'+search_txt)

ff_dir=f_dir+s+'-'+query_txt+'-'+search_txt
fc_name=f_dir+s+'-'+query_txt+'-'+search_txt+'\\'+s+'-'+query_txt+'-'+search_txt+'.csv'

img_dir = ff_dir+"\\images"
os.makedirs(img_dir)
os.chdir(img_dir)

s_time = time.time( )

chrome_path = "C:/data/chromedriver"
driver = webdriver.Chrome(chrome_path)

driver.get(query_url)
time.sleep(3)

time.sleep(5)
element = driver.find_element_by_name("search_query")
element.send_keys(search_txt)
element.submit()
time.sleep(2)

cnt = 1 

def scroll_down(driver):
    driver.execute_script("window.scrollBy(0,3000);")
    time.sleep(5)

if count < 24 :
    page_cnt = 1 
else :
    page_cnt = math.ceil(count/24)

if count > 24 :
    i = 1
    
    while ( i <=  page_cnt) :
        print("화면을 %s 회 아래로 스크롤 합니다" %i)
        scroll_down(driver)
        time.sleep(1)
        i += 1

no_list = []
title_list = []
thumbnail_list = []
views_list = []
channel_list = []
period_list = []
length_lsit = []
summary_list = []


html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
item = soup.find('ytd-section-list-renderer', 'style-scope ytd-two-column-search-results-renderer')
item2 = item.find_all('ytd-video-renderer')
print(item2)

no = 1
for j in item2:

    # 키워드에 따른 변수 크롤링


    # 번호
    print("-"*80)
    print('번호: ', no)
    no_list.append(no)
    no += 1

    
    #ytd-video-renderer



    # 제목
    try:
        title = j.find("yt-formatted-string", "style-scope ytd-video-renderer")
    except:
        title = '제목이 없습니다.'
        print(title.replace("\n",""))
    else:
        title2 = title.get_text()
        print("제목: ", title2)
        title_list.append(title2)

    # 썸네일

    # 조회수
    try:
        views = j.find("span", "style-scope ytd-video-meta-block")   
    except:
        views = '조회수가 없습니다.'
        print(views.replace("\n",""))
    else:
        views2 = views.get_text().replace("조회수 ", "")
        print("조회수: ", views2)
        views_list.append(views2)
    
    # 채널명
    try:
        channel = j.find("yt-formatted-string", "style-scope ytd-channel-name")   
    except:
        channel = '채널명이 없습니다.'
        print(channel.replace("\n",""))
    else:
        channel2 = channel.get_text()
        print("채널명: ", channel2)
        channel_list.append(channel2)
   
    # 기간

    # 길이

    
    
    # 요약  
    try:
        summary = j.find("yt-formatted-string", "metadata-snippet-text-navigation style-scope ytd-video-renderer")   
    except:
        summary = '요약이 없습니다.'
        print(summary.replace("\n",""))
    else:
        summary2 = summary.get_text()
        print("요약: ", summary2)
        summary_list.append(summary2)

        
    if no > count:
        break
    
    print("-"*80)    
    print("\n")


    
    
'''
썸네일
제목
조회수
채널명
기간
길이
요약

기간은?
- 오늘
- 이번주
- 이번달
- 올해
'''

#csv로 저장

df = pd.DataFrame()
df['번호']=pd.Series(no_list)
df['제목']=pd.Series(title_list, dtype="string")
# df['썸네일']
# df['조회수']=pd.Series(views_list, dtype="string")
df['채널명']=pd.Series(channel_list, dtype="string")
df['기간']=pd.Series(period_list, dtype="string")
# df['길이']=pd.Series(length_list, dtype="string")
df['요약']=pd.Series(summary_list, dtype="string")



# 엑셀 형태로 저장하기
df.to_csv(fc_name, encoding="utf-8-sig",index=False)

        
        
        

#마지막 요약정보 출력   
e_time = time.time( )
t_time = e_time - s_time

print("\n")
print("=" *100)
print("총 소요시간: %s 초" %round(t_time,1))
print("총 저장 건수: %s 건 " %count)
print("파일 저장 경로: %s" %fc_name)
print("=" *100)

driver.close( )
# Out:
# ================================================================================
#
#
#                              유튜브 크롤링
#
#
# ================================================================================
#
#
# 1.크롤링할 검색어를 입력하세요: 무한도전
# 2.몇 건을 가져오겠습니까?: 10
# 3.파일을 저장할 폴더명만 쓰세요.(엔터 입력시 C:/data2/에 저장됨):
#
#
#   요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요
# [<ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=XVoisVqgrYw" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/XVoisVqgrYw/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLCWFqxlBT13JkhxgoBtBuSxNZ96aA" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="15분 17초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   15:17
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송 게시자: 옛능 : MBC 옛날 예능 다시보기 8시간 전 15분 조회수 18,996회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=XVoisVqgrYw" id="video-title" title="[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송 게시자: 옛능 : MBC 옛날 예능 다시보기 8시간 전 15분 조회수 18,996회" class="style-scope ytd-video-renderer">[무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 1.8만회</span>
# <span class="style-scope ytd-video-meta-block">8시간 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer">[무도의 7월은 어땠을까?] 치킨이 아니고 크로커다일..? KFC=치킨인 줄 알았던 선발팀   ??? : 너네집에서 모일건데 너도 올래?</yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer">[무도의 7월은 어땠을까?] 치킨이 아니고 크로커다일..? KFC=치킨인 줄 알았던 선발팀   ??? : 너네집에서 모일건데 너도 올래?</yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">새 동영상</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=ySn7zXzuA98" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/ySn7zXzuA98/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLBbg3ZQCwsZ-OngjKxmPvDNsC4k4w" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="18분 11초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   18:11
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송 게시자: 옛능 : MBC 옛날 예능 다시보기 1일 전 18분 조회수 74,286회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=ySn7zXzuA98" id="video-title" title="[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송 게시자: 옛능 : MBC 옛날 예능 다시보기 1일 전 18분 조회수 74,286회" class="style-scope ytd-video-renderer">[무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 7.4만회</span>
# <span class="style-scope ytd-video-meta-block">1일 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20090704 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20090704 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">새 동영상</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=5gEgBSf106Y" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/5gEgBSf106Y/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLC1Vdij01frMX4aj3pIgfFWNevwMA" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="10분 6초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   10:06
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송 게시자: 오분순삭 2개월 전 10분 6초 조회수 2,199,182회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=5gEgBSf106Y" id="video-title" title="전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송 게시자: 오분순삭 2개월 전 10분 6초 조회수 2,199,182회" class="style-scope ytd-video-renderer">전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC9idb-NIhZrI6wkPesc3MUg" spellcheck="false">오분순삭</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     오분순삭
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 219만회</span>
# <span class="style-scope ytd-video-meta-block">2개월 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UC9idb-NIhZrI6wkPesc3MUg">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLRI95ASduGRz4-nbRu3X91TRRW4z7FxZITINM_1OQ=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC9idb-NIhZrI6wkPesc3MUg" spellcheck="false">오분순삭</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     오분순삭
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">회의시간보다 오래 걸리는 무한상사의 점심 메뉴 고르는 시간,,⏱ *</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 다시 보기 ✓옛능에서 관련 에피소드 더보기   ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">회의시간보다 오래 걸리는 무한상사의 점심 메뉴 고르는 시간,,⏱ *</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 다시 보기 ✓옛능에서 관련 에피소드 더보기   ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=MyOoYJPQK9w" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/MyOoYJPQK9w/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLDzk16HTllp4kjxqX282xjjONAsOQ" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="19분 42초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   19:42
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 11개월 전 19분 조회수 2,455,991회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=MyOoYJPQK9w" id="video-title" title="[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 11개월 전 19분 조회수 2,455,991회" class="style-scope ytd-video-renderer">[8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 245만회</span>
# <span class="style-scope ytd-video-meta-block">11개월 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">[무도의 8월은 어땠을까?] 비가 와도 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto">은 멈추지 않는다! 이 위기를 같이 극복할 소중한 친구 찾기 섭외 전화부터 일단 나온다고 ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">[무도의 8월은 어땠을까?] 비가 와도 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto">은 멈추지 않는다! 이 위기를 같이 극복할 소중한 친구 찾기 섭외 전화부터 일단 나온다고 ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=FZ6K0gtS_FM" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/FZ6K0gtS_FM/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLCc0iVBqD8RJbKz2r_IqVboVCZifQ" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="15분 12초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   15:12
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="[무도] 내가 뭘 그렇게 잘못을…😥 오늘이 생일인 듯한(?) 준하의 상처만 남은 스태프 앙케트…💧 ‘10주년 앙케트’ 1편 MBC150425방송 게시자: 옛능 : MBC 옛날 예능 다시보기 2개월 전 15분 조회수 2,222,374회" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=FZ6K0gtS_FM" id="video-title" title="[무도] 내가 뭘 그렇게 잘못을…😥 오늘이 생일인 듯한(?) 준하의 상처만 남은 스태프 앙케트…💧 ‘10주년 앙케트’ 1편 MBC150425방송">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="[무도] 내가 뭘 그렇게 잘못을…😥 오늘이 생일인 듯한(?) 준하의 상처만 남은 스태프 앙케트…💧 ‘10주년 앙케트’ 1편 MBC150425방송 게시자: 옛능 : MBC 옛날 예능 다시보기 2개월 전 15분 조회수 2,222,374회" class="style-scope ytd-video-renderer">[무도] 내가 뭘 그렇게 잘못을…😥 오늘이 생일인 듯한(?) 준하의 상처만 남은 스태프 앙케트…💧 ‘10주년 앙케트’ 1편 MBC150425방송</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 222만회</span>
# <span class="style-scope ytd-video-meta-block">2개월 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLSnFt6ZLg85acDannloXAvjzw-YHbut2SFA4sCP7g=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# ...
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">명수옹 유행어에 애착이 강한가보다 *</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 다시 보기 #오분순삭 #</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> #유행어 ✓ WAVVE ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">명수옹 유행어에 애착이 강한가보다 *</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 다시 보기 #오분순삭 #</span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> #유행어 ✓ WAVVE ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">새 동영상</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>, <ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=EXN45HLMhaI" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="23분 56초" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   23:56
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label='[5月의 무도] 이거 완전 ⚡명수세끼⚡ 아니야~?! 무도 멤버들의 알면서도 속는 무인도 표류기!🚁 "10주년 무인도" 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 1년 전 23분 조회수 3,664,066회' class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=EXN45HLMhaI" id="video-title" title='[5月의 무도] 이거 완전 ⚡명수세끼⚡ 아니야~?! 무도 멤버들의 알면서도 속는 무인도 표류기!🚁 "10주년 무인도" 1편 infinite challenge'>
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label='[5月의 무도] 이거 완전 ⚡명수세끼⚡ 아니야~?! 무도 멤버들의 알면서도 속는 무인도 표류기!🚁 "10주년 무인도" 1편 infinite challenge 게시자: 옛능 : MBC 옛날 예능 다시보기 1년 전 23분 조회수 3,664,066회' class="style-scope ytd-video-renderer">[5月의 무도] 이거 완전 ⚡명수세끼⚡ 아니야~?! 무도 멤버들의 알면서도 속는 무인도 표류기!🚁 "10주년 무인도" 1편 infinite challenge</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer"><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">조회수 366만회</span>
# <span class="style-scope ytd-video-meta-block">1년 전</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="채널로 이동" class="style-scope ytd-video-renderer" href="/channel/UChY4PXxJI0aJYsGT1X6INWA">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UChY4PXxJI0aJYsGT1X6INWA" spellcheck="false">옛능 : MBC 옛날 예능 다시보기</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     옛능 : MBC 옛날 예능 다시보기
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20150425 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">방영일자 : 20150425 </span><span class="bold style-scope yt-formatted-string" dir="auto">무한도전</span><span class="style-scope yt-formatted-string" dir="auto"> 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   동영상 설명에서 가져옴
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer>]
# --------------------------------------------------------------------------------
# 번호:  1
# 제목:  [무도] 🐊우리가 알던 메이커가 아니야🐊 주인 없는 집에 사람 채워드림👨‍👩‍👧‍👦 '무한도전 응원단 : 브라질' 8편 MBC140621방송
# 조회수:  1.8만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  [무도의 7월은 어땠을까?] 치킨이 아니고 크로커다일..? KFC=치킨인 줄 알았던 선발팀   ??? : 너네집에서 모일건데 너도 올래?
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  2
# 제목:  [무도] “엄마! 아빠! 1200원 주세요!!🤬” 환율 생각하는 전자 깡패🤑 혼돈의 중간 점검 ‘올림픽대로 듀엣 가요제’ 3편 MBC090704방송
# 조회수:  7.4만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  방영일자 : 20090704 무한도전 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  3
# 제목:  전국 직장인 10:00~11:30 주업무 = 오늘 점심 메뉴 고르기 | 무한도전⏱오분순삭 MBC111008방송
# 조회수:  219만회
# 채널명:  오분순삭
# 요약:  회의시간보다 오래 걸리는 무한상사의 점심 메뉴 고르는 시간,,⏱ *무한도전 다시 보기 ✓옛능에서 관련 에피소드 더보기   ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  4
# 제목:  [8月의 무도] 비와서 촬영을 못한다고?☔ ㄴㄴ우린 레전드 뽑음ㅋ 위기를 기회로 만드는 레전드의 시작 “우천시 취소 특집” 1편 infinite challenge
# 조회수:  245만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  [무도의 8월은 어땠을까?] 비가 와도 무한도전은 멈추지 않는다! 이 위기를 같이 극복할 소중한 친구 찾기 섭외 전화부터 일단 나온다고 ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  5
# 제목:  [무도] 내가 뭘 그렇게 잘못을…😥 오늘이 생일인 듯한(?) 준하의 상처만 남은 스태프 앙케트…💧 ‘10주년 앙케트’ 1편 MBC150425방송
# 조회수:  222만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  [무도의 4월은 어땠을까?] 무한도전 10주년 기념 스태프 앙케트   Q. 오디오 꺼버리고 싶은 멤버는? Q. 가장 찍고 싶은 멤버 순위는?
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  6
# 제목:  [7月의 무도] 뱃값만 35만원이야 💢 80명 사.비.로 책임지는 쿨(하지 못한)가이 정총무 투어 🚢 ＂시크릿 바캉스＂ 2편 infinite challenge
# 조회수:  290만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  방영일자 : 20100717, 20100724 무한도전 1화부터 FULL버전 다시 보기 (2006년 5월 6일~2018년 3월 31일) → ▷ WAVVE ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  7
# 제목:  [7月의 무도] 까먹었는데요🤔 뜻밖의 웃음참기 메이커 명수와 웃음지옥에 갇힌 다섯 사나이😭 “진짜 사나이” 1편 infinite challenge
# 조회수:  285만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  ... 명의 남자들과 그들을 웃음지옥으로 보내버린 단 한 명의 guy,, 방영일자 : 20170701 무한도전 1화부터 FULL버전 다시 보기 (2006 ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  8
# 제목:  [10月의 무도] “거지 같이 하고 왔어!” 초면부터 물고 뜯는😬 일곱 남자의 진정한 짝꿍 찾기!👬 “짝꿍” 1편 #옛능 (MBC 20111022 방송)
# 조회수:  159만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  눈치 없지만 착한 남자 6호   ⬆모두가 (비)호감을 가지는 감정이 널뛰기하는 남자 7호⬇ 방영일자 : 20111022 무한도전 1화부터 FULL ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  9
# 제목:  [9月의 무도] 스마트폰 무식자도 공짜로 영화를 볼 수 있다?! 함께 해봐요 (내 맘대로) 만원의↗ 하루↘ 💵  “생활계획표” 1편 (MBC 20150919 방송)
# 조회수:  281만회
# 채널명:  옛능 : MBC 옛날 예능 다시보기
# 요약:  ... 김태호' https://youtu.be/E_n9iHXf3kQ '아이디가 있었는데요 없었습니다' https://youtu.be/TFWdN5s2-EU 무한도전 1화부터 FULL ...
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# 번호:  10
# 제목:  🎉경 존버당 축🎉 영혼의 단짝 하와수의 명품 하모니 모음💎| 무한도전⏱오분순삭 MBC091219방송
# 조회수:  27만회
# 채널명:  오분순삭
# 요약:  성악 혹은 발악 *무한도전 다시 보기 ✓ WAVVE ...
#
#
# ====================================================================================================
# 총 소요시간: 16.8 초
# 총 저장 건수: 10 건
# 파일 저장 경로: /data2/2021-07-17-02-03-37-유튜브-무한도전\2021-07-17-02-03-37-유튜브-무한도전.csv
# ====================================================================================================

# %%
#이미지 삽입하기

import win32com.client as win32   #pywin32 , pypiwin32 설치후 동작
import win32api  #파이썬 프롬프트를 관리자 권한으로 실행해야 에러없음
                 #파이썬 쉘을 관리자 권한으로 실행한 후 불러오기로 이 소스 실행하기

excel = win32.gencache.EnsureDispatch('Excel.Application')
wb = excel.Workbooks.Open(fx_name)
sheet = wb.ActiveSheet
sheet.Columns(3).ColumnWidth = 30   #  이미지 가로 사이즈에 맞게 컬럼 크기 조정
row_cnt = cnt+1
sheet.Rows("2:%s" %row_cnt).RowHeight = 120  #  이미지 세로 사이즈에 맞게 로우 크기 조정

ws = wb.Sheets("Sheet1")
col_name2=[]
file_name2=[]

for a in range(2,cnt+2) :
    col_name='C'+str(a)
    col_name2.append(col_name)
    time.sleep(0.3)

for b in range(1,cnt+1) :
    file_name=img_dir+'/'+str(b)+'.jpg'
    file_name2.append(file_name)
    time.sleep(0.3)

for i in range(0,cnt) :
    rng = ws.Range(col_name2[i])
    image = ws.Shapes.AddPicture(file_name2[i], False, True, rng.Left, rng.Top, 130, 100)
    excel.Visible=True
    excel.ActiveWorkbook.Save()
    time.sleep(0.3)
