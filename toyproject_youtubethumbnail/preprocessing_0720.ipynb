# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

img_path = 'C:/Users/tkrhk/Desktop/Chevrolet/bolt_2015/10/H0 (1).jpg'

img = cv.imread(img_path)
plt.imshow(img)

# %%
# blurcode

kernel = np.ones((5,5),np.float32)/25
blur = cv.filter2D(img, -1, kernel)
cv.imshow('original', img)
cv.imshow('blur', blur)

cv.waitKey(27)
cv.destroyallWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-2bb1c7d93471> in <module>
#       7
#       8 cv.waitKey(27)
# ----> 9 cv.destroyallWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destroyallWindows'

# %%
from keras.preprocessing import image

img = image.load_img(img_path, target_size = (500, 500))
img_tensor = image.img_to_array(img)

# %%
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor.shape
# Out:
# (1, 500, 500, 3)

# %%
img_tensor/=255.
img_tensor[0]
# Out:
# array([[[0.8509804 , 0.8862745 , 0.88235295],
#         [0.87058824, 0.91764706, 0.9019608 ],
#         [0.8156863 , 0.8901961 , 0.8666667 ],
#         ...,
#         [0.4392157 , 0.5372549 , 0.65882355],
#         [0.40784314, 0.49803922, 0.62352943],
#         [0.42745098, 0.5176471 , 0.6431373 ]],
#
#        [[0.7058824 , 0.9647059 , 0.9607843 ],
#         [0.61960787, 0.8901961 , 0.8784314 ],
#         [0.5764706 , 0.84705883, 0.8352941 ],
#         ...,
#         [0.4392157 , 0.5372549 , 0.654902  ],
#         [0.42352942, 0.5137255 , 0.6392157 ],
#         [0.45490196, 0.54509807, 0.6666667 ]],
#
#        [[0.33333334, 0.40392157, 0.49803922],
#         [0.3647059 , 0.41960785, 0.5254902 ],
#         [0.3647059 , 0.4       , 0.52156866],
#         ...,
#         [0.4509804 , 0.54509807, 0.654902  ],
#         [0.42352942, 0.5137255 , 0.63529414],
#         [0.4392157 , 0.5294118 , 0.6509804 ]],
#
#        ...,
#
#        [[0.2784314 , 0.27058825, 0.27450982],
#         [0.24705882, 0.22352941, 0.22352941],
#         [0.19215687, 0.1882353 , 0.17254902],
#         ...,
#         [0.1254902 , 0.1254902 , 0.11764706],
#         [0.12941177, 0.13333334, 0.11372549],
#         [0.14117648, 0.13725491, 0.12156863]],
#
#        [[0.2627451 , 0.24705882, 0.23529412],
#         [0.25490198, 0.24313726, 0.22352941],
#         [0.1882353 , 0.18431373, 0.16862746],
#         ...,
#         [0.13333334, 0.13333334, 0.1254902 ],
#         [0.15686275, 0.16078432, 0.14117648],
#         [0.13725491, 0.14901961, 0.12156863]],
#
#        [[0.1764706 , 0.15686275, 0.17254902],
#         [0.2627451 , 0.2627451 , 0.25490198],
#         [0.16862746, 0.17254902, 0.15294118],
#         ...,
#         [0.15294118, 0.15686275, 0.13725491],
#         [0.15686275, 0.16470589, 0.14509805],
#         [0.13333334, 0.15294118, 0.1254902 ]]], dtype=float32)

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20,20)

plt.imshow(img_tensor[0])
plt.show()

# %%
import pandas as pd

# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-452e4478b1f2> in <module>
# ----> 1 from imageai.Detection import ObjectDetection
#       2 import os
#
# ModuleNotFoundError: No module named 'imageai'

# %%
from imageai.Detection import ObjectDetection
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-452e4478b1f2> in <module>
# ----> 1 from imageai.Detection import ObjectDetection
#       2 import os
#
# ModuleNotFoundError: No module named 'imageai'

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp38-cp38-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tkrhk\anaconda3\lib\site-packages (from opencv-python) (1.19.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.3.56Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)

# %%
import cv2
import numpy as np

# Load Yolo
net = cv2.dnn.readNet("yolov4.weights", "yolov4.cfg")
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-d1356f99b5bf> in <module>
#       3
#       4 # Load Yolo
# ----> 5 net = cv2.dnn.readNet("yolov4.weights", "yolov4.cfg")
#       6 classes = []
#       7 with open("coco.names", "r") as f:
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\dnn\src\darknet\darknet_importer.cpp:207: error: (-212:Parsing error) Failed to parse NetParameter file: yolov4.cfg in function 'cv::dnn::dnn4_v20210608::readNetFromDarknet'

# %%
pip install opencv-contrib-python==3.4.13.47 --force-reinstall
# Out:
# Collecting opencv-contrib-python==3.4.13.47
#   Using cached opencv_contrib_python-3.4.13.47-cp38-cp38-win_amd64.whl (36.4 MB)
# Collecting numpy>=1.17.3
#   Using cached numpy-1.21.1-cp38-cp38-win_amd64.whl (14.0 MB)
# Installing collected packages: numpy, opencv-contrib-python
#   Attempting uninstall: numpyNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\tkrhk\\anaconda3\\Lib\\site-packages\\~.mpy\\.libs\\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\tkrhk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\tkrhk\anaconda3\lib\site-packages)
#     Found existing installation: numpy 1.21.1
#     Uninstalling numpy-1.21.1:
#       Successfully uninstalled numpy-1.21.1

# %%
# Out:
#   File "<ipython-input-6-58cd65c9e55b>", line 1
#     아무것도 안된다.........
#          ^
# SyntaxError: invalid syntax
